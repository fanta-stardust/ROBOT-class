# %%
"""
机器人导航和屏幕识别主程序

此程序实现了机器人导航到指定位置，识别屏幕，进行图像分类，然后与上位机通信的功能。
"""

# 导入必要的模块
import os

import cv2
import numpy as np
from action import ActionControl
from classfier import Classifier
from communication import Channel

# 导入自定义模块
from map2 import load_tag_pos
from navigation import RobotNavigator
from PIL import Image
from regiondetector import RegionDetector
from main import classify_and_communicate

os.system('sh ./stop_sys_ttyPS0.sh')

def main():
    """主函数，执行导航、识别、分类和通信功能"""

    # 相机参数
    camera_matrix = np.array(
        [[787.1377, 0, 0], [0, 786.2276, 0], [972.0599, 576.0402, 1]], dtype=np.float32
    ).T

    dist_coeffs = np.array([0.2253, -0.1053, -0.0963, 0, 0], dtype=np.float32)

    # 加载AprilTag位置数据
    tag_poses = load_tag_pos()
    # 巡航目标点列表
    goal_positions = [
        np.array([180,50]),
        np.array([220,80]),
        np.array([220,80]),
        np.array([220,230]),
        np.array([140,230]),
        np.array([50,200]),
        np.array([60,30]),
        # 可以继续添加更多目标点
    ]

    # 初始化动作控制器
    action_controller = ActionControl()
    # 初始化通信通道（只初始化一次）
    channel = Channel("192.168.1.254", "idiot", "password1")  # 使用正确的IP和凭据
    # 初始化团队，获取目标
    try:
        target = channel.initialize_team()
        print(f"目标花朵类型: {target}")
    except Exception as e:
        print(f"通信初始化出错: {e}")
        return

    # 分类器只需初始化一次
    classifier = Classifier("design_1.bit")
    # 区域检测器只需初始化一次
    detector = RegionDetector()

    flower_types = [
        "bailianhua",
        "chuju",
        "hehua",
        "juhua",
        "lamei",
        "lanhua",
        "meiguihua",
        "shuixianhua",
        "taohua",
        "yinghua",
        "yuanweihua",
        "zijinghua",
    ]
    goal_pos=None
    navigator = RobotNavigator(
    camera_matrix, dist_coeffs, tag_poses, goal_pos,
    region_detector=detector,
    classifier=classifier,
    channel=channel,
    flower_types=flower_types,
    target=target
)
    for idx, goal_pos in enumerate(goal_positions):
        print(f"\n=== 巡航到第{idx + 1}个目标点: {goal_pos} ===")
        navigator.goal_pos = goal_pos
        navigator.navigate()
        print(f"=== 到达第{idx + 1}个目标点 ===")


if __name__ == "__main__":
    main()
# Out:
# 目标花朵类型: juhua
# min_x: 0
# min_y: 0
# max_x: 294
# max_y: 294
# x_width: 59
# y_width: 59
#
# === 巡航到第1个目标点: [180  50] ===
# 正在处理nav_1_front.jpg
# Tag22面积合适，开始处理
# tag22不在中心
# Tag23面积合适，开始处理
# 23cannot find a screen
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag 42 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: -1
# 位置定位不合理
# 正在处理nav_1_left.jpg
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag33面积合适，开始处理
# Tag33找到了对应屏幕
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 7
# 检测到的花朵类型: shuixianhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 0
# 屏幕区域已提取并保存至: nav_left_region_1_tag33.jpg
#
# === 开始分类阶段 ===
# 分类结果: 7
# 检测到的花朵类型: shuixianhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 1
# 左转头前方向None posNone
# 正在处理nav_1_right.jpg
# Tag 42 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 右转头前方向None posNone
# 定位失败
# 正在处理nav_2_front.jpg
# Tag 14 面积过小，跳过
# Tag16面积合适，开始处理
# Tag16找到了对应屏幕
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag23面积合适，开始处理
# Tag23找到了对应屏幕
# Tag 54 不是柱上tag，跳过
# 将对总共3个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag16.jpg
#
# === 开始分类阶段 ===
# 分类结果: 7
# 检测到的花朵类型: shuixianhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 2
# 屏幕区域已提取并保存至: nav_front_region_2_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag23.jpg
#
# === 开始分类阶段 ===
# 分类结果: 7
# 检测到的花朵类型: shuixianhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 3
# 当前方向：[[-0.50990648]
#  [ 0.86017263]]
# [ 243.34683277  105.61581746   30.51028199]
# 重新规划路径
# Find goal
# 路径[245.0, 240.0, 235.0, 230.0, 225.0, 220.0, 215.0, 210.0, 205.0, 200.0, 195.0, 190.0, 185.0, 180.0]
# 路径[105.0, 100.0, 95.0, 90.0, 85.0, 80.0, 75.0, 70.0, 65.0, 60.0, 55.0, 50.0, 50.0, 50.0]
# 当前位置(245.0, 105.0, 'down-left') 方向[[-0.50990648]
#  [ 0.86017263]] 目标方向(-1, -1)
# 执行fastForward07 1次
# 正在处理nav_3_front.jpg
# Tag2面积合适，开始处理
# 2cannot find a screen
# Tag5面积合适，开始处理
# Tag5找到了对应屏幕
# Tag12面积合适，开始处理
# 12cannot find a screen
# Tag36面积合适，开始处理
# 36cannot find a screen
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag5.jpg
#
# === 开始分类阶段 ===
# 分类结果: 4
# 检测到的花朵类型: lamei
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 4
# 位置定位不合理
# 正在处理nav_3_left.jpg
# Tag3面积合适，开始处理
# 3cannot find a screen
# Tag 97 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向[[ 0.20576643]
#  [-0.97673699]] pos[ 227.11595062   68.29504198   31.89279117]
# 转头后方向：[[-0.8755036 ]
#  [-0.47942508]] pos[ 227.11595062   68.29504198   31.89279117]
# [ 227.11595062   68.29504198   31.89279117]
# 重新规划路径
# Find goal
# 路径[225.0, 220.0, 215.0, 210.0, 205.0, 200.0, 195.0, 190.0, 185.0, 180.0]
# 路径[70.0, 70.0, 70.0, 70.0, 70.0, 70.0, 65.0, 60.0, 55.0, 50.0]
# 当前位置(225.0, 70.0, 'left') 方向[[-0.8755036 ]
#  [-0.47942508]] 目标方向(-1, 0)
# 执行fastForward04 1次
# 正在处理nav_4_front.jpg
# Tag8面积合适，开始处理
# 8cannot find a screen
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag33面积合适，开始处理
# Tag33找到了对应屏幕
# Tag 47 不是柱上tag，跳过
# Tag 54 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 5
# 屏幕区域已提取并保存至: nav_front_region_4_tag33.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.9593288 ]
#  [ 0.28225731]]
# [ 215.4259121    81.6196526    32.67332918]
# 重新规划路径
# Find goal
# 路径[215.0, 210.0, 205.0, 200.0, 195.0, 190.0, 185.0, 180.0]
# 路径[80.0, 75.0, 70.0, 65.0, 60.0, 55.0, 50.0, 50.0]
# 当前位置(215.0, 80.0, 'down-left') 方向[[-0.9593288 ]
#  [ 0.28225731]] 目标方向(-1, -1)
# 执行fastForward04 1次
# 正在处理nav_5_front.jpg
# Tag2面积合适，开始处理
# 2cannot find a screen
# Tag5面积合适，开始处理
# Tag5找到了对应屏幕
# Tag8面积合适，开始处理
# Tag8找到了对应屏幕
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_5_tag5.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_5_tag8.jpg
#
# === 开始分类阶段 ===
# 分类结果: 1
# 检测到的花朵类型: chuju
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 6
# 正在处理nav_5_left.jpg
# Tag 43 不是柱上tag，跳过
# Tag 97 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向None posNone
# 正在处理nav_5_right.jpg
# Tag5面积合适，开始处理
# 5cannot find a screen
# Tag8面积合适，开始处理
# Tag8找到了对应屏幕
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag33面积合适，开始处理
# 33cannot find a screen
# Tag36面积合适，开始处理
# 36cannot find a screen
# Tag 47 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_right_region_5_tag8.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_right_region_5_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 5
# 右转头前方向[[-0.95681166]
#  [ 0.28754192]] pos[ 214.4746851    63.62784033   33.13099601]
# 转头后方向：[[-0.63103647]
#  [-0.77457206]] pos[ 214.4746851    63.62784033   33.13099601]
# [ 214.4746851    63.62784033   33.13099601]
# 重新规划路径
# Find goal
# 路径[215.0, 210.0, 205.0, 200.0, 195.0, 190.0, 185.0, 180.0]
# 路径[65.0, 65.0, 65.0, 65.0, 65.0, 60.0, 55.0, 50.0]
# 当前位置(215.0, 65.0, 'left') 方向[[-0.63103647]
#  [-0.77457206]] 目标方向(-1, 0)
# 执行fastForward04 1次
# 正在处理nav_6_front.jpg
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag33面积合适，开始处理
# 33cannot find a screen
# Tag36面积合适，开始处理
# Tag36找到了对应屏幕
# Tag 47 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_6_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 4
# 屏幕区域已提取并保存至: nav_front_region_6_tag36.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 3
# 当前方向：[[-0.93556206]
#  [ 0.35096744]]
# [ 196.02643161   80.89175328   32.97320396]
# 重新规划路径
# Find goal
# 路径[195.0, 195.0, 195.0, 195.0, 190.0, 185.0, 180.0]
# 路径[80.0, 75.0, 70.0, 65.0, 60.0, 55.0, 50.0]
# 当前位置(195.0, 80.0, 'down') 方向[[-0.93556206]
#  [ 0.35096744]] 目标方向(0, -1)
# 执行fastForward04 1次
# 正在处理nav_7_front.jpg
# Tag2面积合适，开始处理
# 2cannot find a screen
# Tag5面积合适，开始处理
# Tag5找到了对应屏幕
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_7_tag5.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 位置定位不合理
# 正在处理nav_7_left.jpg
# Tag 43 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向None posNone
# 正在处理nav_7_right.jpg
# Tag5面积合适，开始处理
# Tag5找到了对应屏幕
# Tag8面积合适，开始处理
# 8cannot find a screen
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag 47 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_right_region_7_tag5.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_right_region_7_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 2
# 右转头前方向[[-0.99882972]
#  [-0.02344513]] pos[ 193.71288039   57.51994389   34.46778698]
# 转头后方向：[[-0.35964396]
#  [-0.93213019]] pos[ 193.71288039   57.51994389   34.46778698]
# [ 193.71288039   57.51994389   34.46778698]
# 到达目标点
# === 到达第1个目标点 ===
#
# === 巡航到第2个目标点: [220  80] ===
# 正在处理nav_1_front.jpg
# Tag2面积合适，开始处理
# 2cannot find a screen
# Tag5面积合适，开始处理
# Tag5找到了对应屏幕
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag5.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 位置定位不合理
