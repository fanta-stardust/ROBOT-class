# %%
"""
机器人导航和屏幕识别主程序

此程序实现了机器人导航到指定位置，识别屏幕，进行图像分类，然后与上位机通信的功能。
"""

# 导入必要的模块
import os

import cv2
import numpy as np
from action import ActionControl
from classfier import Classifier
from communication import Channel

# 导入自定义模块
from map2 import load_tag_pos
from navigation import RobotNavigator
from PIL import Image
from regiondetector import RegionDetector
from main import classify_and_communicate

os.system('sh ./stop_sys_ttyPS0.sh')

#def init():

    # 相机参数新2
#camera_matrix = np.array(
#    [[787.1377, 0, 0], [0, 786.2276, 0], [972.0599, 576.0402, 1]], dtype=np.float32
#).T

#dist_coeffs = np.array([0.2253, -0.1053, -0.0963, 0, 0], dtype=np.float32)
camera_matrix = np.array(
        [[785.7108, 0, 0], [0, 794.9039, 0], [928.6918, 528.5677, 1]], dtype=np.float32
    ).T
dist_coeffs = np.array([0.2672, -0.2865, 0.0875, 0, 0], dtype=np.float32)
# 加载AprilTag位置数据
tag_poses = load_tag_pos()
# 巡航目标点列表
goal_positions = [
    np.array([170,50,1,1]),
    np.array([215,90,0,1]),
    np.array([215,205,-1,-1]),
    np.array([120,220,0,-1]),
    np.array([40,230,0,-1]),
    np.array([80,60,1,1]),
    # 可以继续添加更多目标点
]
start_to_goal_dict={
    1:goal_positions,
    2:[goal_positions[1], goal_positions[2], goal_positions[3], goal_positions[4], goal_positions[5], goal_positions[0]],
    3:[goal_positions[1], goal_positions[2], goal_positions[3], goal_positions[4], goal_positions[5], goal_positions[0]],
    4:[goal_positions[2], goal_positions[3], goal_positions[4], goal_positions[5], goal_positions[0], goal_positions[1]],
    5:[goal_positions[2], goal_positions[3], goal_positions[4], goal_positions[5], goal_positions[0], goal_positions[1]],
    6:[goal_positions[3], goal_positions[4], goal_positions[5], goal_positions[0], goal_positions[1], goal_positions[2]],
    7:[goal_positions[4], goal_positions[5], goal_positions[0], goal_positions[1], goal_positions[2], goal_positions[3]],
    8:[goal_positions[4], goal_positions[5], goal_positions[0], goal_positions[1], goal_positions[2], goal_positions[3]],
    9:[goal_positions[5], goal_positions[0], goal_positions[1], goal_positions[2], goal_positions[3], goal_positions[4]],
    10:[goal_positions[5], goal_positions[0], goal_positions[1], goal_positions[2], goal_positions[3], goal_positions[4]],
}

def get_goal_sequence(start_point):
    if start_point in start_to_goal_dict:
        return start_to_goal_dict[start_point]
    else:
        raise ValueError("起点不在预定义的起点列表中")
        
# 初始化动作控制器
action_controller = ActionControl()
# 初始化通信通道（只初始化一次）
channel = Channel("192.168.1.254", "故障机器人", "password1")  # 使用正确的IP和凭据
# 初始化团队，获取目标
try: 
    target = channel.initialize_team()
    print(f"目标花朵类型: {target}")
except Exception as e:
    print(f"通信初始化出错: {e}")
#    return

# 分类器只需初始化一次
classifier = Classifier("design_1.bit")
# 区域检测器只需初始化一次
detector = RegionDetector()

flower_types = [
    "bailianhua",
    "chuju",
    "hehua",
    "juhua",
    "lamei",
    "lanhua",
    "meiguihua",
    "shuixianhua",
    "taohua",
    "yinghua",
    "yuanweihua",
    "zijinghua",
]
goal_pos=None
navigator = RobotNavigator(
camera_matrix, dist_coeffs, tag_poses, goal_pos,
region_detector=detector,
classifier=classifier,
channel=channel,
flower_types=flower_types,
target=target
)
# Out:
# 目标花朵类型: hehua
# min_x: 0
# min_y: 0.0
# max_x: 294
# max_y: 294
# x_width: 59
# y_width: 59.0

# %%
my_goal_positions = get_goal_sequence(1)
for idx, goal_pos in enumerate(my_goal_positions):
    print(f"\n=== 巡航到第{idx + 1}个目标点: {goal_pos} ===")
    navigator.goal_pos = goal_pos[:2]
    now_pos,now_direction = navigator.navigate()
    print(f"=== 到达第{idx + 1}个目标点 ===")
    print(f"正在从{now_direction}转向{goal_pos[2:]}")
    action_controller.turn_to_direction(now_direction,goal_pos[2:])
# Out:
# === 巡航到第1个目标点: [170  50   1   1] ===
# 正在处理nav_1_front.jpg
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag14面积合适，开始处理
# Tag14找到了对应屏幕
# Tag 47 不是柱上tag，跳过
# Tag 50 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 1
# 检测到的花朵类型: chuju
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: -1
# 屏幕区域已提取并保存至: nav_front_region_1_tag14.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 0
# 位置定位不合理
# 正在处理nav_1_left.jpg
# Tag5面积合适，开始处理
# Tag5找到了对应屏幕
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag 97 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag5.jpg
#
# === 开始分类阶段 ===
# 分类结果: 10
# 检测到的花朵类型: yuanweihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 1
# 屏幕区域已提取并保存至: nav_left_region_1_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 3
# 检测到的花朵类型: juhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 2
# 左转头前方向[[-0.63721255]
#  [-0.74953348]] pos[ 159.0380556    36.84394927   27.54246724]
# 转头后方向：[[-0.90177736]
#  [ 0.3932402 ]] pos[ 159.0380556    36.84394927   27.54246724]
# [ 159.0380556    36.84394927   27.54246724]
# 到达目标点 位置[ 159.0380556    36.84394927   27.54246724] 方向[[-0.90177736]
#  [ 0.3932402 ]]
# === 到达第1个目标点 ===
# 正在从[[-0.90177736]
#  [ 0.3932402 ]]转向[1 1]
#
# === 巡航到第2个目标点: [215  90   0   1] ===
# 正在处理nav_1_front.jpg
# Tag1面积合适，开始处理
# Tag1找到了对应屏幕
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag1.jpg
#
# === 开始分类阶段 ===
# 分类结果: 10
# 检测到的花朵类型: yuanweihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 3
# 位置定位不合理
# 正在处理nav_1_left.jpg
# Tag36面积合适，开始处理
# Tag36找到了对应屏幕
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag36.jpg
#
# === 开始分类阶段 ===
# 分类结果: 10
# 检测到的花朵类型: yuanweihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 4
# 位置定位不合理
# 左转头前方向None posNone
# 正在处理nav_1_right.jpg
# 将对总共0个合理屏幕进行分类通信
# 右转头前方向None posNone
# 定位失败
# 正在处理nav_2_front.jpg
# Tag1面积合适，开始处理
# Tag1找到了对应屏幕
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag1.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 10
# 检测到的花朵类型: yuanweihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 5
# 位置定位不合理
# 正在处理nav_2_left.jpg
# Tag14面积合适，开始处理
# Tag14找到了对应屏幕
# Tag 28 面积过小，跳过
# Tag 29 面积过小，跳过
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag36面积合适，开始处理
# Tag36找到了对应屏幕
# Tag 47 不是柱上tag，跳过
# 将对总共3个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_2_tag14.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_2_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_2_tag36.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 左转头前方向[[-0.0707811 ]
#  [ 0.99748782]] pos[ 172.48333896   11.9377286    34.44911925]
# 转头后方向：[[ 0.93440252]
#  [ 0.35620758]] pos[ 172.48333896   11.9377286    34.44911925]
# [ 172.48333896   11.9377286    34.44911925]
# 重新规划路径
# Find goal
# 路径[170.0, 170.0, 170.0, 170.0, 170.0, 170.0, 170.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0]
# 路径[10.0, 15.0, 20.0, 25.0, 30.0, 35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0, 90.0]
# 当前位置(170.0, 10.0, 'up') 方向[[ 0.93440252]
#  [ 0.35620758]] 目标方向(0, 1)
# 执行fastForward04 1次
# 正在处理nav_3_front.jpg
# Tag14面积合适，开始处理
# Tag14找到了对应屏幕
# Tag29面积合适，开始处理
# Tag29找到了对应屏幕
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag36面积合适，开始处理
# Tag36找到了对应屏幕
# 将对总共4个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag14.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag29.jpg
#
# === 开始分类阶段 ===
# 分类结果: 11
# 检测到的花朵类型: zijinghua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 6
# 屏幕区域已提取并保存至: nav_front_region_3_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag36.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.013142  ]
#  [ 0.99990621]]
# [ 167.27283093   26.64328457   34.36299128]
# 重新规划路径
# Find goal
# 路径[165.0, 165.0, 165.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0]
# 路径[25.0, 30.0, 35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0, 90.0]
# 当前位置(165.0, 25.0, 'up') 方向[[-0.013142  ]
#  [ 0.99990621]] 目标方向(0, 1)
# 执行fastForward04 1次
# 正在处理nav_4_front.jpg
# Tag14面积合适，开始处理
# Tag14找到了对应屏幕
# Tag29面积合适，开始处理
# Tag29找到了对应屏幕
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag36面积合适，开始处理
# Tag36找到了对应屏幕
# Tag 45 不是柱上tag，跳过
# 将对总共4个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag14.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag29.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag36.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.09786579]
#  [ 0.99516904]]
# [ 166.18824823   49.52033597   33.09108332]
# 当前位置(165.0, 40.0, 'up-right') 方向[[-0.09786579]
#  [ 0.99516904]] 目标方向(1, 1)
# 执行fastForward07 1次
# 正在处理nav_5_front.jpg
# Tag32面积合适，开始处理
# 32cannot find a screen
# Tag 44 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_5_left.jpg
# Tag 18 面积过小，跳过
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag33面积合适，开始处理
# 33cannot find a screen
# Tag36面积合适，开始处理
# Tag36找到了对应屏幕
# Tag 45 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_5_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_5_tag36.jpg
#
# === 开始分类阶段 ===
# 分类结果: 9
# 检测到的花朵类型: yinghua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 5
# 左转头前方向[[-0.07361355]
#  [ 0.99699459]] pos[ 211.82048768   56.61994651   31.90497762]
# 转头后方向：[[ 0.93311129]
#  [ 0.35877638]] pos[ 211.82048768   56.61994651   31.90497762]
# [ 211.82048768   56.61994651   31.90497762]
# 重新规划路径
# Find goal
# 路径[210.0, 210.0, 210.0, 210.0, 210.0, 210.0, 210.0, 215.0]
# 路径[55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0, 90.0]
# 当前位置(210.0, 55.0, 'up') 方向[[ 0.93311129]
#  [ 0.35877638]] 目标方向(0, 1)
# 执行fastForward04 1次
# 正在处理nav_6_front.jpg
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag 45 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_6_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 11
# 检测到的花朵类型: zijinghua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 6
# 屏幕区域已提取并保存至: nav_front_region_6_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 位置定位不合理
# 正在处理nav_6_left.jpg
# Tag12面积合适，开始处理
# 12cannot find a screen
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag33面积合适，开始处理
# 33cannot find a screen
# Tag36面积合适，开始处理
# 36cannot find a screen
# Tag 47 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_6_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 左转头前方向[[-0.82876639]
#  [ 0.55948472]] pos[ 212.1431811    73.17454817   33.94694967]
# 转头后方向：[[ 0.29592091]
#  [ 0.955148  ]] pos[ 212.1431811    73.17454817   33.94694967]
# [ 212.1431811    73.17454817   33.94694967]
# 到达目标点 位置[ 212.1431811    73.17454817   33.94694967] 方向[[ 0.29592091]
#  [ 0.955148  ]]
# === 到达第2个目标点 ===
# 正在从[[ 0.29592091]
#  [ 0.955148  ]]转向[0 1]
#
# === 巡航到第3个目标点: [215 205  -1  -1] ===
# 正在处理nav_1_front.jpg
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag29面积合适，开始处理
# 29cannot find a screen
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag33面积合适，开始处理
# 33cannot find a screen
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 位置定位不合理
# 正在处理nav_1_left.jpg
# Tag8面积合适，开始处理
# 8cannot find a screen
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag33面积合适，开始处理
# Tag33找到了对应屏幕
# Tag36面积合适，开始处理
# 36cannot find a screen
# Tag 47 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag33.jpg
#
# === 开始分类阶段 ===
# 分类结果: 9
# 检测到的花朵类型: yinghua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 7
# 左转头前方向[[-0.96423211]
#  [ 0.26066726]] pos[ 211.0631604    70.1082221    32.50049844]
# 转头后方向：[[-0.02930335]
#  [ 0.99841489]] pos[ 211.0631604    70.1082221    32.50049844]
# [ 211.0631604    70.1082221    32.50049844]
# 当前位置(210.0, 85.0, 'up-right') 方向[[-0.02930335]
#  [ 0.99841489]] 目标方向(1, 1)
# 执行fastForward04 1次
# 正在处理nav_2_front.jpg
# Tag32面积合适，开始处理
# 32cannot find a screen
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_2_left.jpg
# Tag14面积合适，开始处理
# 14cannot find a screen
# Tag16面积合适，开始处理
# Tag16找到了对应屏幕
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# Tag33面积合适，开始处理
# 33cannot find a screen
# Tag 54 不是柱上tag，跳过
# Tag 59 不是柱上tag，跳过
# 将对总共3个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_2_tag16.jpg
#
# === 开始分类阶段 ===
# 分类结果: 0
# 检测到的花朵类型: bailianhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 8
# 屏幕区域已提取并保存至: nav_left_region_2_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_2_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 左转头前方向[[-0.24169016]
#  [ 0.9689969 ]] pos[ 226.28043263   72.45972543   43.07081526]
# 转头后方向：[[ 0.85770589]
#  [ 0.51157573]] pos[ 226.28043263   72.45972543   43.07081526]
# [ 226.28043263   72.45972543   43.07081526]
# 重新规划路径
# Find goal
# 路径[225.0, 225.0, 225.0, 225.0, 225.0, 225.0, 225.0, 225.0, 225.0, 225.0, 225.0, 225.0, 220.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0]
# 路径[70.0, 75.0, 80.0, 85.0, 90.0, 95.0, 100.0, 105.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0]
# 当前位置(225.0, 70.0, 'up') 方向[[ 0.85770589]
#  [ 0.51157573]] 目标方向(0, 1)
# 执行fastForward07 1次
# 正在处理nav_3_front.jpg
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag23面积合适，开始处理
# 23cannot find a screen
# Tag32面积合适，开始处理
# Tag32找到了对应屏幕
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag32.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.03689885]
#  [ 0.99732899]]
# [ 228.518182    114.80363568   25.58401703]
# 当前位置(225.0, 125.0, 'up-left') 方向[[-0.03689885]
#  [ 0.99732899]] 目标方向(-1, 1)
# 执行fastForward04 1次
# 正在处理nav_4_front.jpg
# Tag14面积合适，开始处理
# Tag14找到了对应屏幕
# Tag16面积合适，开始处理
# Tag16找到了对应屏幕
# Tag22面积合适，开始处理
# Tag22找到了对应屏幕
# Tag23面积合适，开始处理
# Tag23找到了对应屏幕
# 将对总共4个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag14.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag16.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag22.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag23.jpg
#
# === 开始分类阶段 ===
# 分类结果: 9
# 检测到的花朵类型: yinghua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 9
# 当前方向：[[-0.61990266]
#  [ 0.78446717]]
# [ 214.10587575  127.87554127   34.96242   ]
# 当前位置(215.0, 135.0, 'up') 方向[[-0.61990266]
#  [ 0.78446717]] 目标方向(0, 1)
# 执行fastForward07 1次
# 正在处理nav_5_front.jpg
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_5_left.jpg
# Tag17面积合适，开始处理
# 17cannot find a screen
# Tag22面积合适，开始处理
# tag22不在中心
# Tag23面积合适，开始处理
# 23cannot find a screen
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向[[-0.32378171]
#  [ 0.94611163]] pos[ 221.51619801  164.15709045   33.0084022 ]
# 转头后方向：[[ 0.81205939]
#  [ 0.58354208]] pos[ 221.51619801  164.15709045   33.0084022 ]
# [ 221.51619801  164.15709045   33.0084022 ]
# 重新规划路径
# Find goal
# 路径[220.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0, 215.0]
# 路径[165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0]
# 当前位置(220.0, 165.0, 'up-left') 方向[[ 0.81205939]
#  [ 0.58354208]] 目标方向(-1, 1)
# 执行fastForward04 1次
# 正在处理nav_6_front.jpg
# Tag17面积合适，开始处理
# 17cannot find a screen
# Tag23面积合适，开始处理
# 23cannot find a screen
# Tag26面积合适，开始处理
# 26cannot find a screen
# Tag 38 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 当前方向：[[-0.39405889]
#  [ 0.91897245]]
# [ 214.2593128  174.4714427   32.3083417]
# 当前位置(215.0, 170.0, 'up') 方向[[-0.39405889]
#  [ 0.91897245]] 目标方向(0, 1)
# 执行fastForward04 1次
# 正在处理nav_7_front.jpg
# Tag17面积合适，开始处理
# Tag17找到了对应屏幕
# Tag18面积合适，开始处理
# tag18不在中心
# Tag26面积合适，开始处理
# 26cannot find a screen
# Tag 38 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_7_tag17.jpg
#
# === 开始分类阶段 ===
# 分类结果: 6
# 检测到的花朵类型: meiguihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 10
# 当前方向：[[-0.13383716]
#  [ 0.99090162]]
# [ 210.23675393  194.7637182    31.99630334]
# 到达目标点 位置[ 210.23675393  194.7637182    31.99630334] 方向[[-0.13383716]
#  [ 0.99090162]]
# === 到达第3个目标点 ===
# 正在从[[-0.13383716]
#  [ 0.99090162]]转向[-1 -1]
#
# === 巡航到第4个目标点: [120 220   0  -1] ===
# 正在处理nav_1_front.jpg
# Tag 12 面积过小，跳过
# Tag18面积合适，开始处理
# 18cannot find a screen
# Tag23面积合适，开始处理
# Tag23找到了对应屏幕
# Tag34面积合适，开始处理
# 34cannot find a screen
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag23.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 位置定位不合理
# 正在处理nav_1_left.jpg
# Tag2面积合适，开始处理
# Tag2找到了对应屏幕
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag29面积合适，开始处理
# 29cannot find a screen
# Tag33面积合适，开始处理
# Tag33找到了对应屏幕
# Tag34面积合适，开始处理
# Tag34找到了对应屏幕
# 将对总共4个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag2.jpg
#
# === 开始分类阶段 ===
# 分类结果: 7
# 检测到的花朵类型: shuixianhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 11
# 屏幕区域已提取并保存至: nav_left_region_1_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag33.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag34.jpg
#
# === 开始分类阶段 ===
# 分类结果: 6
# 检测到的花朵类型: meiguihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 12
# 左转头前方向[[-0.24610547]
#  [-0.96924178]] pos[ 223.86317051  177.3720539    36.10765598]
# 转头后方向：[[-0.9989996 ]
#  [-0.04469167]] pos[ 223.86317051  177.3720539    36.10765598]
# [ 223.86317051  177.3720539    36.10765598]
# 重新规划路径
# Open set is empty..
# 正在处理nav_2_front.jpg
# Tag12面积合适，开始处理
# Tag12找到了对应屏幕
# Tag17面积合适，开始处理
# Tag17找到了对应屏幕
# Tag18面积合适，开始处理
# Tag18找到了对应屏幕
# Tag23面积合适，开始处理
# Tag23找到了对应屏幕
# Tag 54 不是柱上tag，跳过
# 将对总共4个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag12.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag17.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag18.jpg
#
# === 开始分类阶段 ===
# 分类结果: 6
# 检测到的花朵类型: meiguihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 13
# 屏幕区域已提取并保存至: nav_front_region_2_tag23.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.99477816]
#  [ 0.09019876]]
# [ 222.26433882  182.9709274    34.58598095]
# 重新规划路径
# Find goal
# 路径[220.0, 215.0, 210.0, 205.0, 200.0, 200.0, 200.0, 195.0, 190.0, 185.0, 180.0, 175.0, 170.0, 165.0, 160.0, 155.0, 150.0, 145.0, 140.0, 135.0, 130.0, 125.0, 120.0]
# 路径[185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 225.0, 220.0]
# 当前位置(220.0, 185.0, 'up-left') 方向[[-0.99477816]
#  [ 0.09019876]] 目标方向(-1, 1)
# 执行fastForward04 1次
# 正在处理nav_3_front.jpg
# Tag17面积合适，开始处理
# Tag17找到了对应屏幕
# Tag18面积合适，开始处理
# Tag18找到了对应屏幕
# Tag23面积合适，开始处理
# 23cannot find a screen
# Tag 37 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag17.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag18.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.92203093]
#  [ 0.38501209]]
# [ 200.66001548  195.3654836    33.50382939]
# 当前位置(200.0, 205.0, 'up') 方向[[-0.92203093]
#  [ 0.38501209]] 目标方向(0, 1)
# 执行fastForward04 1次
# 正在处理nav_4_front.jpg
# Tag26面积合适，开始处理
# 26cannot find a screen
# Tag28面积合适，开始处理
# Tag28找到了对应屏幕
# Tag 38 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_4_tag28.jpg
#
# === 开始分类阶段 ===
# 分类结果: 10
# 检测到的花朵类型: yuanweihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 14
# 当前方向：[[ 0.23876902]
#  [ 0.94798207]]
# [ 226.14923323  211.92667639   43.10372281]
# 重新规划路径
# Find goal
# 路径[225.0, 220.0, 215.0, 210.0, 205.0, 200.0, 195.0, 190.0, 185.0, 180.0, 175.0, 170.0, 165.0, 160.0, 155.0, 150.0, 145.0, 140.0, 135.0, 130.0, 125.0, 120.0]
# 路径[210.0, 210.0, 210.0, 210.0, 210.0, 215.0, 220.0, 225.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 230.0, 225.0, 220.0]
# 当前位置(225.0, 210.0, 'left') 方向[[ 0.23876902]
#  [ 0.94798207]] 目标方向(-1, 0)
# 执行fastForward04 1次
# 正在处理nav_5_front.jpg
# Tag17面积合适，开始处理
# Tag17找到了对应屏幕
# Tag23面积合适，开始处理
# Tag23找到了对应屏幕
# Tag 30 面积过小，跳过
# Tag 37 不是柱上tag，跳过
# Tag 53 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_5_tag17.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_5_tag23.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.88004972]
#  [ 0.4709018 ]]
# [ 203.00646343  210.36092838   44.3120911 ]
# 当前位置(205.0, 210.0, 'up-left') 方向[[-0.88004972]
#  [ 0.4709018 ]] 目标方向(-1, 1)
# 执行fastForward04 1次
# 正在处理nav_6_front.jpg
# Tag17面积合适，开始处理
# 17cannot find a screen
# Tag 37 不是柱上tag，跳过
# Tag 53 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 位置定位不合理
# 正在处理nav_6_left.jpg
# Tag16面积合适，开始处理
# Tag16找到了对应屏幕
# Tag18面积合适，开始处理
# 18cannot find a screen
# Tag23面积合适，开始处理
# 23cannot find a screen
# Tag24面积合适，开始处理
# 24cannot find a screen
# Tag 53 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_6_tag16.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 左转头前方向[[-0.93654988]
#  [-0.34973081]] pos[ 188.50067061  225.3332728    33.06387209]
# 转头后方向：[[-0.60561748]
#  [ 0.79540227]] pos[ 188.50067061  225.3332728    33.06387209]
# [ 188.50067061  225.3332728    33.06387209]
# 当前位置(185.0, 230.0, 'left') 方向[[-0.60561748]
#  [ 0.79540227]] 目标方向(-1, 0)
# 执行fastForward07 1次
# 正在处理nav_7_front.jpg
# Tag17面积合适，开始处理
# 17cannot find a screen
# Tag18面积合适，开始处理
# tag18不在中心
# 将对总共0个合理屏幕进行分类通信
# 位置定位不合理
# 正在处理nav_7_left.jpg
# Tag11面积合适，开始处理
# Tag11找到了对应屏幕
# Tag12面积合适，开始处理
# tag12不在中心
# Tag15面积合适，开始处理
# 15cannot find a screen
# Tag16面积合适，开始处理
# Tag16找到了对应屏幕
# Tag 60 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_7_tag11.jpg
#
# === 开始分类阶段 ===
# 分类结果: 5
# 检测到的花朵类型: lanhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 15
# 屏幕区域已提取并保存至: nav_left_region_7_tag16.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 左转头前方向[[-0.98112242]
#  [-0.17885485]] pos[ 163.22459029  252.60282334   28.3281494 ]
# 转头后方向：[[-0.45493145]
#  [ 0.88748388]] pos[ 163.22459029  252.60282334   28.3281494 ]
# [ 163.22459029  252.60282334   28.3281494 ]
# 重新规划路径
# Find goal
# 路径[165.0, 160.0, 155.0, 150.0, 145.0, 140.0, 135.0, 130.0, 125.0, 120.0]
# 路径[255.0, 250.0, 245.0, 240.0, 235.0, 230.0, 225.0, 220.0, 220.0, 220.0]
# 当前位置(165.0, 255.0, 'down-left') 方向[[-0.45493145]
#  [ 0.88748388]] 目标方向(-1, -1)
# 执行fastForward07 1次
# 正在处理nav_8_front.jpg
# Tag15面积合适，开始处理
# 15cannot find a screen
# Tag16面积合适，开始处理
# Tag16找到了对应屏幕
# Tag 40 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_8_tag16.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.95176131]
#  [-0.27978492]]
# [ 125.80149412  235.40472526   28.12104236]
# 到达目标点 位置[ 125.80149412  235.40472526   28.12104236] 方向[[-0.95176131]
#  [-0.27978492]]
# === 到达第4个目标点 ===
# 正在从[[-0.95176131]
#  [-0.27978492]]转向[ 0 -1]
#
# === 巡航到第5个目标点: [ 40 230   0  -1] ===
# 正在处理nav_1_front.jpg
# Tag8面积合适，开始处理
# Tag8找到了对应屏幕
# Tag15面积合适，开始处理
# 15cannot find a screen
# Tag16面积合适，开始处理
# Tag16找到了对应屏幕
# Tag34面积合适，开始处理
# tag34不在中心
# Tag 55 不是柱上tag，跳过
# Tag 61 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_1_tag8.jpg
#
# === 开始分类阶段 ===
# 分类结果: 4
# 检测到的花朵类型: lamei
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 16
# 屏幕区域已提取并保存至: nav_front_region_1_tag16.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[-0.57699733]
#  [-0.8154866 ]]
# [ 137.43688454  229.30086304   28.14241091]
# 当前位置(130.0, 220.0, 'left') 方向[[-0.57699733]
#  [-0.8154866 ]] 目标方向(-1, 0)
# 执行fastForward04 1次
# 正在处理nav_2_front.jpg
# Tag 40 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_2_left.jpg
# Tag8面积合适，开始处理
# 8cannot find a screen
# Tag15面积合适，开始处理
# Tag15找到了对应屏幕
# Tag16面积合适，开始处理
# 16cannot find a screen
# Tag 61 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_2_tag15.jpg
#
# === 开始分类阶段 ===
# 分类结果: 6
# 检测到的花朵类型: meiguihua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 17
# 左转头前方向[[-0.52005181]
#  [-0.85395996]] pos[ 115.52044027  244.57616551   34.65769776]
# 转头后方向：[[-0.9678621 ]
#  [ 0.25088734]] pos[ 115.52044027  244.57616551   34.65769776]
# [ 115.52044027  244.57616551   34.65769776]
# 重新规划路径
# Find goal
# 路径[115.0, 110.0, 105.0, 100.0, 95.0, 90.0, 85.0, 80.0, 75.0, 70.0, 65.0, 60.0, 55.0, 50.0, 45.0, 40.0]
# 路径[245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 245.0, 240.0, 235.0, 230.0]
# 当前位置(115.0, 245.0, 'left') 方向[[-0.9678621 ]
#  [ 0.25088734]] 目标方向(-1, 0)
# 执行fastForward07 1次
# 正在处理nav_3_front.jpg
# Tag 39 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_3_left.jpg
# Tag15面积合适，开始处理
# 15cannot find a screen
# Tag 52 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向[[-0.63688591]
#  [-0.7651043 ]] pos[  81.77266644  234.84624527   30.05815485]
# 转头后方向：[[-0.91658848]
#  [ 0.38842479]] pos[  81.77266644  234.84624527   30.05815485]
# [  81.77266644  234.84624527   30.05815485]
# 重新规划路径
# Find goal
# 路径[80.0, 75.0, 70.0, 65.0, 60.0, 55.0, 50.0, 45.0, 40.0]
# 路径[235.0, 235.0, 235.0, 235.0, 235.0, 235.0, 235.0, 235.0, 230.0]
# 当前位置(80.0, 235.0, 'left') 方向[[-0.91658848]
#  [ 0.38842479]] 目标方向(-1, 0)
# 执行fastForward04 1次
# 正在处理nav_4_front.jpg
# Tag 51 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_4_left.jpg
# Tag13面积合适，开始处理
# 13cannot find a screen
# Tag15面积合适，开始处理
# Tag15找到了对应屏幕
# Tag 51 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_4_tag15.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 左转头前方向[[ 0.1554409]
#  [-0.9868454]] pos[  53.04230882  231.2995434    31.98837492]
# 转头后方向：[[-0.89973313]
#  [-0.4341728 ]] pos[  53.04230882  231.2995434    31.98837492]
# [  53.04230882  231.2995434    31.98837492]
# 到达目标点 位置[  53.04230882  231.2995434    31.98837492] 方向[[-0.89973313]
#  [-0.4341728 ]]
# === 到达第5个目标点 ===
# 正在从[[-0.89973313]
#  [-0.4341728 ]]转向[ 0 -1]
#
# === 巡航到第6个目标点: [80 60  1  1] ===
# 正在处理nav_1_front.jpg
# Tag15面积合适，开始处理
# 15cannot find a screen
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_1_left.jpg
# Tag15面积合适，开始处理
# Tag15找到了对应屏幕
# Tag21面积合适，开始处理
# Tag21找到了对应屏幕
# Tag24面积合适，开始处理
# 24cannot find a screen
# Tag26面积合适，开始处理
# 26cannot find a screen
# Tag 53 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag15.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_left_region_1_tag21.jpg
#
# === 开始分类阶段 ===
# 分类结果: 7
# 检测到的花朵类型: shuixianhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 18
# 位置定位不合理
# 左转头前方向None posNone
# 正在处理nav_1_right.jpg
# 将对总共0个合理屏幕进行分类通信
# 右转头前方向None posNone
# 定位失败
# 正在处理nav_2_front.jpg
# Tag11面积合适，开始处理
# 11cannot find a screen
# Tag15面积合适，开始处理
# Tag15找到了对应屏幕
# Tag21面积合适，开始处理
# tag21不在中心
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_2_tag15.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[ 0.28943735]
#  [-0.95684622]]
# [  59.98626203  239.46821529   34.58190405]
# 重新规划路径
# Find goal
# 路径[60.0, 60.0, 60.0, 60.0, 55.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 80.0, 80.0]
# 路径[240.0, 235.0, 230.0, 225.0, 220.0, 215.0, 210.0, 205.0, 200.0, 195.0, 190.0, 185.0, 180.0, 175.0, 170.0, 165.0, 160.0, 155.0, 150.0, 145.0, 140.0, 135.0, 130.0, 125.0, 120.0, 115.0, 110.0, 105.0, 100.0, 95.0, 90.0, 85.0, 80.0, 75.0, 70.0, 65.0, 60.0]
# 当前位置(60.0, 240.0, 'down') 方向[[ 0.28943735]
#  [-0.95684622]] 目标方向(0, -1)
# 执行fastForward04 1次
# 正在处理nav_3_front.jpg
# Tag11面积合适，开始处理
# Tag11找到了对应屏幕
# Tag13面积合适，开始处理
# 13cannot find a screen
# Tag15面积合适，开始处理
# 15cannot find a screen
# Tag 50 不是柱上tag，跳过
# Tag 51 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_3_tag11.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[ 0.22028225]
#  [-0.97541903]]
# [  59.9983474   218.00407361   33.93807913]
# 当前位置(60.0, 225.0, 'down-left') 方向[[ 0.22028225]
#  [-0.97541903]] 目标方向(-1, -1)
# 执行fastForward04 1次
# 正在处理nav_4_front.jpg
# Tag11面积合适，开始处理
# tag11不在中心
# Tag 51 不是柱上tag，跳过
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_4_left.jpg
# Tag 2 面积过小，跳过
# Tag11面积合适，开始处理
# Tag11找到了对应屏幕
# Tag13面积合适，开始处理
# 13cannot find a screen
# Tag 51 不是柱上tag，跳过
# Tag 55 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_left_region_4_tag11.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 左转头前方向[[ 0.34165336]
#  [-0.93978837]] pos[  37.86319352  215.01013293   32.64815102]
# 转头后方向：[[-0.80083821]
#  [-0.59882164]] pos[  37.86319352  215.01013293   32.64815102]
# [  37.86319352  215.01013293   32.64815102]
# 当前位置(50.0, 215.0, 'down') 方向[[-0.80083821]
#  [-0.59882164]] 目标方向(0, -1)
# 执行fastForward07 2次
# 正在处理nav_5_front.jpg
# Tag7面积合适，开始处理
# tag7不在中心
# Tag11面积合适，开始处理
# Tag11找到了对应屏幕
# Tag 48 不是柱上tag，跳过
# 将对总共1个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_5_tag11.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 当前方向：[[ 0.05263218]
#  [-0.99030964]]
# [  10.54630959  127.52373078   39.98098116]
# 重新规划路径
# Find goal
# 路径[10.0, 15.0, 20.0, 25.0, 30.0, 35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 80.0, 80.0]
# 路径[130.0, 125.0, 120.0, 115.0, 110.0, 105.0, 100.0, 100.0, 100.0, 95.0, 90.0, 85.0, 80.0, 75.0, 70.0, 65.0, 60.0]
# 当前位置(10.0, 130.0, 'down-right') 方向[[ 0.05263218]
#  [-0.99030964]] 目标方向(1, -1)
# 执行fastForward04 1次
# 正在处理nav_6_front.jpg
# Tag1面积合适，开始处理
# Tag1找到了对应屏幕
# Tag7面积合适，开始处理
# Tag7找到了对应屏幕
# Tag 47 不是柱上tag，跳过
# Tag 48 不是柱上tag，跳过
# 将对总共2个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_6_tag1.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_6_tag7.jpg
#
# === 开始分类阶段 ===
# 分类结果: 5
# 检测到的花朵类型: lanhua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 19
# 当前方向：[[ 0.41715645]
#  [-0.90824356]]
# [  35.94766973  124.03859002   39.83319194]
# 重新规划路径
# Find goal
# 路径[35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 80.0, 80.0, 80.0, 80.0]
# 路径[125.0, 120.0, 115.0, 110.0, 105.0, 100.0, 95.0, 90.0, 85.0, 80.0, 75.0, 70.0, 65.0, 60.0]
# 当前位置(35.0, 125.0, 'down-right') 方向[[ 0.41715645]
#  [-0.90824356]] 目标方向(1, -1)
# 执行fastForward07 1次
# 正在处理nav_7_front.jpg
# Tag1面积合适，开始处理
# Tag1找到了对应屏幕
# Tag7面积合适，开始处理
# Tag7找到了对应屏幕
# Tag35面积合适，开始处理
# Tag35找到了对应屏幕
# 将对总共3个合理屏幕进行分类通信
# 屏幕区域已提取并保存至: nav_front_region_7_tag1.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_7_tag7.jpg
#
# === 开始分类阶段 ===
# 分类结果: 2
# 检测到的花朵类型: hehua
#
# === 开始通信阶段 ===
# 已经是目标花，跳过通信
# 屏幕区域已提取并保存至: nav_front_region_7_tag35.jpg
#
# === 开始分类阶段 ===
# 分类结果: 9
# 检测到的花朵类型: yinghua
#
# === 开始通信阶段 ===
# 成功改变花朵！分数: 20
# 当前方向：[[ 0.84366417]
#  [-0.53163263]]
# [ 69.73856726  88.55644582  28.89613304]
# 当前位置(80.0, 80.0, 'down') 方向[[ 0.84366417]
#  [-0.53163263]] 目标方向(0, -1)
# 执行fastForward04 1次
# 正在处理nav_8_front.jpg
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_8_left.jpg
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向None posNone
# 正在处理nav_8_right.jpg
# 将对总共0个合理屏幕进行分类通信
# 右转头前方向None posNone
# 定位失败
# 正在处理nav_9_front.jpg
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_9_left.jpg
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向None posNone
# 正在处理nav_9_right.jpg
# 将对总共0个合理屏幕进行分类通信
# 右转头前方向None posNone
# 定位失败
# 正在处理nav_10_front.jpg
# 将对总共0个合理屏幕进行分类通信
# 正在处理nav_10_left.jpg
# 将对总共0个合理屏幕进行分类通信
# 左转头前方向None posNone
# 正在处理nav_10_right.jpg
# 将对总共0个合理屏幕进行分类通信
# 右转头前方向None posNone
# 定位失败
# 正在处理nav_11_front.jpg
# 将对总共0个合理屏幕进行分类通信
